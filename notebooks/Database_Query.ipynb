# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0                            name                domain  \
# 0     5153810                 playlive events  playliveevents.co.uk
# 1     5175005  luphiel financial services inc           luphiel.net
# 2     2681386      juneau veterinary hospital                   NaN
# 3       13359              manaserv bcn, s.l.                   NaN
# 4     3081575                     the farmery        thefarmery.com
# 5     5298542     first impression landscapes  first-impression.net
# 6     3107498              sundown state bank         sundownsb.com
# 7     4446034                   perlan museum       perlanmuseum.is
# 8     4019893                         inconet                   NaN
# 9      149981         ruskim seafoods limited          ruskim.co.uk
#
#    year founded                          industry size range  \
# 0        2007.0                   events services     1 - 10
# 1        1985.0                financial services     1 - 10
# ...

# %%
df.sample(n=10000, random_state=42)
# Out:
#        Unnamed: 0                                               name  \
# 75721     2545761                                scouting 't volbert
# 80184     1610752                                www.groupshoppy.com
# 19864      945382                                annino incorporated
# 76699     6509285                            rattan consulting, inc.
# 92991     5562782                                 at aerial services
# ...           ...                                                ...
# 5002      1732427                                           net data
# 30151      333404                         madaffer enterprises, inc.
# 93194     2971547  website developer at right-click websites and ...
# 73199     5724888                              appcoder software ltd
# 74479     2246783                       fort scott community college
#
#                           domain  year founded  \
# 75721                 volbert.nl        1977.0
# ...

# %%
df.to_csv('output-10000.csv', index=False)

# %%
df = pd.read_csv('output.csv')
import sqlite3, csv

# %%
conn = sqlite3.connect('database.db')

# %%
cur = conn.cursor()

# %%
with open('output.csv') as f:
   reader = csv.reader(f)
   data = list(reader)

# %%
cur.execute('DROP TABLE companies')

# %%
cur.execute('''CREATE TABLE companies (
    id INTEGER PRIMARY KEY,
    "name" TEXT NOT NULL,
    "domain" TEXT,
    "year founded" INTEGER,
    "industry" TEXT,
    "size range" TEXT,
    "locality" TEXT,
    "country" TEXT,
    "linkedin url" TEXT,
    "current employee estimate" INTEGER,
    "total employee estimate" INTEGER
);''')

# %%
df
# Out:
#             id                            name                domain  \
# 0      5153810                 playlive events  playliveevents.co.uk
# 1      5175005  luphiel financial services inc           luphiel.net
# 2      2681386      juneau veterinary hospital                   NaN
# 3        13359              manaserv bcn, s.l.                   NaN
# 4      3081575                     the farmery        thefarmery.com
# ...        ...                             ...                   ...
# 99995   796707                     munti magic        muntimagic.com
# 99996   355305         woodson impex pvt. ltd.                   NaN
# 99997  4962019                   nv consulting      nv-consulting.fr
# 99998  3940170         open group of companies          openstaff.ru
# 99999  6871417          wood advertising sales                   NaN
#
#        year founded                             industry size range  \
# 0            2007.0                      events services     10-Jan
# ...

# %%
df.to_sql('companies', conn, if_exists='append', index=False)
# Out:
# 100000

# %%
df = pd.read_sql_query("""SELECT * FROM companies WHERE "industry" = 'music';""", conn)

# %%
df
# Out:
#           id                                      name  \
# 0        286                     eden music production
# 1        526           greensleeves publishing limited
# 2      16005                              pier bernitz
# 3      16977                attina's music store, inc.
# 4      19047                    epicentre records sàrl
# ..       ...                                       ...
# 676  7116803                   jeugd en muziek brussel
# 677  7123562  vista murrieta high school band boosters
# 678  7124889         bangladesh jute mills corporation
# 679  7135179                 audible sound productions
# 680  7145495                           zero level ltd.
#
#                       domain  year founded industry size range  \
# 0    edenmusicproduction.com        2014.0    music     10-Jan
# 1                       None           NaN    music     10-Jan
# 2                       None        2010.0    music     10-Jan
# ...
